# %% [markdown]
# <a href="https://colab.research.google.com/github/vaammpyy/Physics/blob/main/Random%20Walk/2D/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand
from matplotlib.animation import FuncAnimation
from IPython import display

# %%
N=int(input("Enter number of steps: "))
line_width=input("Enter line width for the plot(Use smaller number for larger steps): ")
if N>=1000:
  case=input("Type 'yes' for animation or press 'enter' for just plot \nWarning: Animating for steps>1000 can take upto anywhere from serveral minutes to serveral hours to compile. For steps=10000 it usually takes 20 mins to compile: ")
else:
  case=input("Type 'yes' for animation or press 'enter' for just plot: ")
print("\n")
seed=(0,0)   
x=[0]*N
y=[0]*N
x[0]=seed[0]
y[0]=seed[1]
 
for i in range(1,N):
  xx=x[i-1]+rand.choice([-1,1,0])
  yy=y[i-1]+rand.choice([-1,1,0])
  x[i]=xx
  y[i]=yy
x=np.array(x)
y=np.array(y)
 
x_min=np.floor(x.min())
x_max=np.ceil(x.max())
y_min=np.floor(y.min())
y_max=np.ceil(y.max())


fig=plt.figure(facecolor='white',figsize=(12,12))
plt.plot(x,y,'k',linewidth=line_width)
plt.xticks(np.arange(x_min-1,x_max+1,step=1.0),labels=" ")
plt.yticks(np.arange(y_min-1,y_max+1,step=1.0),labels=" ")
plt.xlim((x_min-1,x_max+1))
plt.ylim((y_min-1,y_max+1))
plt.axis('scaled')
plt.title("Random Walk  N={}".format(N),fontsize=18)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False 
    ) # labels along the bottom edge are off
plt.show()


if case=="yes":

  fig2= plt.figure(figsize=(12,12),facecolor='white')
  
  plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='both',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=False,         # ticks along the top edge are off
      labelbottom=False) # labels along the bottom edge are off
  plt.tick_params(
      axis='y',          # changes apply to the x-axis
      which='both',      # both major and minor ticks are affected
      left=False,
      labelleft=False) # labels along the bottom edge are off 
  plt.xticks(np.arange(x_min-1,x_max+1,step=1.0),labels=" ")
  plt.yticks(np.arange(y_min-1,y_max+1,step=1.0),labels=" ")
  
  plt.xlim((x_min-1,x_max+1))
  plt.ylim((y_min-1,y_max+1))
  #plt.title("Random Walk  N={}".format(N))
  
  lines=plt.plot([],'k',[],'ro',linewidth=line_width)
  line=lines[0]
  time_text=plt.title('',fontsize=18,loc='left')
  points=plt.plot([],'ro')
  point=points[0]
  
  def animate(frame):
    if frame<N:
      time=frame*20/1000 
      line.set_data((x[:(frame+1)],y[:(frame+1)]))
      time_text.set_text("Time[s] ={}".format(time)) 
      point.set_data((x[frame],y[frame]))

  anim=FuncAnimation(fig2,animate,frames=N+50,interval=20)
  video=anim.to_html5_video()
  html=display.HTML(video)
  display.display(html)
  
  plt.close()
# Out:
# Enter number of steps: 100
# Enter line width for the plot(Use smaller number for larger steps): 1
# Type 'yes' for animation or press 'enter' for just plot: yes
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-67f026a50bbc> in <module>
#      28 fig=plt.figure(facecolor='white',figsize=(12,12))
#      29 plt.plot(x,y,'k',linewidth=line_width)
# ---> 30 plt.xticks(np.arange(x_min-1,x_max+1,step=1.0),labels=" ")
#      31 plt.yticks(np.arange(y_min-1,y_max+1,step=1.0),labels=" ")
#      32 plt.xlim((x_min-1,x_max+1))
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
#    1816         l.update(kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# ~/.local/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1709             # remove all tick labels, so only error for > 0 ticklabels
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1711                 raise ValueError(
#    1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (8), usually from a call to set_ticks, does not match the number of ticklabels (1).
